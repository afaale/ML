# %% [markdown]
# <a href="https://colab.research.google.com/github/afaale/ML/blob/ML/RNN_fromscratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# copy pasted. To analyze later.

# %%
import numpy as np


# To read the training data and make a vocabulary and dictionary to index the chars
class DataReader:
    def __init__(self, path, seq_length):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        #self.data = "some really long text to test this. maybe not perfect but should get you going."
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets
       
    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %%
def zero_init(a,b):
    return np.zeros((a,b))

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output
        
        # memory vars for adagrad, 
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))
        
    

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)
    
    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = zero_init(self.vocab_size,1)
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap
    
    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity 
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam) 
            return dU, dW, dV, db, dc

    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update
                
                
    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = zero_init(self.vocab_size, 1)
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = zero_init(self.vocab_size,1)
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.01
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):

        #initialize input vector
        x = zero_init(self.vocab_size, 1)
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = zero_init(self.vocab_size,1)
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 25
data_reader = DataReader('/content/drive/MyDrive/input.txt', seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# D,geSK-eHg;.jmtXJ e pj  MnaA-X$ZMCZBsA;ZG$ Q,I h:eRJ'th$h:cllZRE?E,OMQDOC&VUBDNA!Yu,Y$
# kO$bq'gKt3ApLI'vmLiyz-V&CdrDz-jirRMSCmsItBgiYhKq!UgnCii,$.KcXFjYI?jb3VOhmKoqbvP?V,Yi3b; -CS:tFEuIObMS.IZRmW&QFT;j
#
#
# iter :0, loss:104.359672
#
# S:
# GnbnOieu ao te Aledsa
# thumh ro aer
#
# He:dao tolmwionasMarol rat tonr yi:tdtn
# .i verts:ig gaosnariOo
#  he aoeeneiMcon  ie hoof CigcsCon,d
# ABUNBSm, .coket' ara': wiOe I ooehe ivod gdl Souanpes wy whe
#
#
# iter :500, loss:96.242219
# ; ulk bove; fife gnnel
# w,
# Hoscinf,
# Ar tiot nothire; badrgisg lot. af Tine 'rerrnen kute
# Th cuisr -ithe n ora gh yoow thir:,
#
# T Yutinntk th orge :ro yedtirtor t, thoc ak wac thethar nid thor mave lelin
#
#
# iter :1000, loss:85.041676
# oo bnd you pout ui he nolv yat yeten. pnos fom Ioud,
# te s? fas taviser bat ad lntk fou sacerd weou y thasvout
#
# ; made orentht aric ofesentus angor gadT an ttt sit, ioW oo he domy pount angwen?
# W.
# Foki
#
#
# iter :1500, loss:76.121423
# scfanof wole I the cave mo; wemed' toug. Sop sune sopoule go and gire latsher.
# Weyttiuteas de co herlend trewil,ak.
# IAr
# Lefe hex slonr thit meed fof hittursto
# lit Co oug rpeoul 'icoare hein gondlad th
#
#
# iter :2000, loss:69.949081
# 'ur: thcin cosgozle thicctcos your werely Hisghe
# Letg ows to aaines we spyo opram your
#
# MEEEENVUBNT; youve, wh aze, blat.
#
# Then, no,ir I fpo wow she shats
#
# Cefonstciule
# fudiv, Cson wfi: nows:
# I hesdin
#
#
# iter :2500, loss:65.362001
# n me nous,
# He pperoug, Coriud:
# Yomed the goad thas, Ghe mir desutis topol ther wakar'; elas tuce bit. runt agtee weet,
# Lo' the ghid drat nocoz wos gotrelr
# Bn touth pilen, in! thy atse the mesters sure
#
#
# iter :3000, loss:61.874302
# Thligha fan bei shave busrof aczhourd toyanste then yourerlw.
# Bun, the hime an forl of lell buot phous?
# We bast don tundein
# I afen pat ofr wa
# loRr:
# Gof lat ingwartinors.
# Con swesean thals iwe tho id t
#
#
# iter :3500, loss:59.200883
# MENENENIALUS:
# I awe ansiren, gnomize weallsneg hexve?
#
# SICINIA,
# Vs It ocior tiongus lyowe thiks ay, in than for phake.
#
# BRUTUS:-I
# I! deer ist feousll  bersere yomible tour gida mu feghout bydead
# With
#
#
# iter :4000, loss:57.559390
# ear:
# Whetee:
# Of havl int Oy romh irs thin me! mare thiit,'; Yan,
# Ang bmirter.
#
# Covi. I ou I armun:
# Lacin ho hall baatsesar I v thein an, Iy hecen:
# Whan wiy
# Nit if memusets?
#
# I thmmm Wo er.!
# ; cerasthi
#
#
# iter :4500, loss:56.842615
#  nos thien daes s nin orefliud worc he scass to at sharn, menen cerent hatt Go prand hinns,
# Was of pore harlear horand it we reis ak l antrin; wonshrell.
# Thiillet;
# Caver taibli as torserst uforres the
#
#
# iter :5000, loss:56.225435
# If not
# The prouncind grecown.
#
# IOH
# NENeUS:rof dran fice the Nroutsion besf
# sis to mirigger-;
# Aseat do, thin, fo arepere rons't-ir wath thive hant trea.
#
# Fesw rou mast sare.
#
# MENENIUS:
# Ore vulln ald me
#
#
# iter :5500, loss:55.833768
# f canind thas!
#
# dnhis the sand yows lerkour.
# Lovee$ Hes'd
# 'l?
#
# BeUS:
# Yow while louspeth.
#
# Sid sjebled:
# Soll Ant ake orders.
#
# Fir the cours you mome dins, whrete bures, wof mess Tse arath puwm!
# To eis
#
#
# iter :6000, loss:55.556805
# ' I fevill chaust EI wy thoy
# Thou fous dlold ckeme, be;ktssant andels!
# Hpe chat the hant are conpornong usteess!
# Aorsothuetit the bawh the'lr and dovave,
# Wengor thef he by, must;
# Frreter mus'th-hy moe
#
#
# iter :6500, loss:56.416537
# f aer po,
# Qstimet rote mety.
#
# GOCINE
# SLANER:
# Whin Ip hhe and thacm, I higes disty ig your Ifll; tid tourr me' wordh mig'd, lly ceakenr this and koth and
# wonkes, Ifea'. Aiw hiblor fong.
# Ance Ronghassar
#
#
# iter :7000, loss:55.674781
# s!
# Ryou tuurd;
# Nor thee stheld'lsbes hepe in, somenont to ind ay atd mind I hem motild him mias! jod it ib hat ore a fuuve tuse tyathar deedher there yof be un iifh core shees,
# Cadr foo shath,
# Oh my o
#
#
# iter :7500, loss:55.257486
# e snoul furis Ire that anl wo Made dacert ? hard nfent, the gut seodan-s: andof cagce one he livee
# Dou make
# And lopll
# To hall that the mush and,
# C sheand;
# I wing.
# We breert prverer'r ou it atll wong c
#
#
# iter :8000, loss:54.819932
#  peat-'ne
# And mave thir thou sid, and or we death heraes mowh ince cothurs ubus doonpre; no mus meed,
# premus co my,
# Whard lath toue, rave rude mon baous grat bskeaod dowd as yom.
# Hes.
#
# Q.DESY:
# Ghvigcr
#
#
# iter :8500, loss:54.745322
# han anr.
# Af wize bukan.
# Of menisel.
#
# COATEMS:
# Gamytudingurdok to beavy
#
# QLvumt orle saId whis gome's
# Mind eadter I crimider'd haes ou grosi walst greangwalt, yow youcorjy ain oup.
#
# HUCEN
# BREN
# SI
# KBRTH
#
#
# iter :9000, loss:54.533356
# , mas lond.
#
# CKNyKHAM:
# Yould im, gake lackI il you hegf yop hely fot iigher lirepons aod wath the amurl, wenghin we to ho meales,
# That
# My to yous, ar it llit
# I stous thour sit lroword thin iest, noth
#
#
# iter :9500, loss:53.394526
#
# Wis fpere'; mpaeser;
# Goly toll,
#
# F dowh of !evenghs,
# Thig peabtsied, Wher wis, of lelloun Me hat Eorg lethous is nives? now me, nome Ickedtel-;
# The the so.
#
# LOUCHAS:
# By liten,
# Heve sey.
# By hoalSult i
#
#
# iter :10000, loss:53.067839
# ontiAs'reant neto the vaad then histel. Rand hle, Lord besthint that klay tharl:
# Id af rrazy chteandof, I morl, nmeinke om his in Gompiugh Gove.
#
# RTEY:
# Fo,
# And me.
#
# not kevene and me lowantttle? uise
#
#
# iter :10500, loss:52.780534
# thour upeptosped:
# AM to the?
#
# QAAVET
# MICHARD:
# I aly anvend,
# And and oavrong cowsader to all mimen kyaat of the monean Pfale rivy arear ward op to leree ay nower to fowir ming.
#
# KIVKINGLITAM:
# Teat and
#
#
# iter :11000, loss:53.129545
# Ty chin, thinecs thead ceve hapen ferem, thes inostand anditum of and heab, by puchil' youthe yous to lake doth the eofendfue.
#
# LIZAVEMII And morced ant.
#
# KING RICH:
# I barts ige ensst-youk hobr forthe
#
#
# iter :11500, loss:51.468921
# Etel montow, in thaig.
#
# KI!
# ORCOR:
# Ny the crosceders
#
# LAOST:
# Why croms pithest
# Will'ngerood.
#
# CLERICIBBHI I'ens!
#
# KING
# SI HENCID:
# Wres hee
# Fear tead havim hagfanens.
# Thiovsiw, the, nirt tho bean hiof
#
#
# iter :12000, loss:50.999384
# uturmeimy chat all youl hee limy to eaedt:
# Rhat thank not on theriry poul Igheant you tha-d ceietongen ow bime
# Ard
# Mame uproin
# I Lavbykent'st visteld thou fime in kyorus pramedell has to roul toulust
#
#
# iter :12500, loss:52.368710
# fthisingake, willland doth his pus artontise's revircunesterd sstaregh do ther bus!
# Tun, my rionstsh sood sarel:
# Laves
# is kime sarosheart eyfand roods my ho his focire al'the the .
# Whall?
# The ant of I
#
#
# iter :13000, loss:53.037419
# erake
# I sert in:
# But ant, reisene.
#
# KING RICHATBTHRISPT:
# OL,
# Gent then my vinghoring, loje wa qursh:
# Hetward co dims, me xarle; notll kinghrongur!
# What benderen's lore of:
# And histh, youll tregh-y, hi
#
#
# iter :13500, loss:53.339999
# onges'd uckall'y manga hald ritheing.
#
# KONG:
# Themthen shaw or me;
# Thy maghed trife to staths;
#
# DuNBHEEN Bit end alf:
# Pryobrtssig cand lounp a be moth, agind God thos telst and ther shein you drouf,
# -o
#
#
# iter :14000, loss:53.121752
# d peare;
# Thing:
# Our hate this fall for has the gots de thorkot yfusnopend whast, the bith if bowe,
# Artil seigf gigh he as wrats I he conivefond? laghakengord nos genceld
# Depe nouved ofr laret
# Tho guno
#
#
# iter :14500, loss:52.881039
# s tapuctay,
# And nee.
# Uke hingy to clorcy ware rame aad estigh for sins ceved noughrese fwithur,
# Thie artergforl co, anen bley to, Purvingy now theald douss me sach
# I hich wis, hoo seateriy, dare I co,
#
#
# iter :15000, loss:52.553013
#  longring
# And reove?
# Buty knoje:
# And apist upEeple and llises.
#
# BUGHEN PBORI EI?
#
# BUKE NO HRAKICN RARG
# RENT:
# Ot as Lemepre! my wheer gecelans'd yourp to vis theeth cast colls beds my whefples to thine
#
#
# iter :15500, loss:52.553574
# ncest?
#
# I han:
# Shate Rietforingen ing pondewt cous to dech bis ponteend,
# Ay sower Whonging ot o bole of thels of wend go meing o han Ine the the deatoun tofe hey thick mage of I deld,
# O be as thee off
#
#
# iter :16000, loss:52.130376
# perserus olderne to eut: sum to lanten:
# Hefe dearjers they, intrey agen I hage ander?
#
# HERKI:
# To with dalengs myjond,
# And in digit
# Fill hithe my mpan in simse are; mornobed greland u blof theue in bur
#
#
# iter :16500, loss:51.860284
#
# Tous thim in roonve-t our ous o groll mile this emwhe fil'voud netal to majespert, may ar he bate,
# And that pare os this sper hin, beand? Furd where be wedinbeit suarmbepeld yoush thepers 'now me'd t
#
#
# iter :17000, loss:51.013822
# aldilad?
# Sur lad.
# And prath swarbott hin your grome; chomt do, hagis ay
# This ainsty, no theard on in in posbert; sweoben noundtd gorty rist to liap to pensle int is thinge mbeard tratortsep?
#
# DUKE
# Be
#
#
#
# iter :17500, loss:50.043138
# Their what so partsher Larusen.
#
# GQRYOLI:
# Mowrecshoug furd of sor cross,
# And but so sheatops eroon me' ligh, we, ched do doen Moie sisterrit,
# My,
# Heer the do, 'I delors was is word.
#
# TORIO:
# Manondwis
#
#
# iter :18000, loss:51.056707
# nroter,
# Five it that iw thun dood hist; youll wilk aud shoud.
#
# Noren sight: ligh in stoud-ge st
# youm, hinged stire.
#
# O paren-- blly thee: hiug fark becetes. Surs to my rpairt nigh not here Nore matter
#
#
# iter :18500, loss:51.911229
# my'l.
# Ying, more hle taed gagal gom!
#
# AOL:
# Nen, same re.
#
# RERADU::
# O dais furd trise: a mare not yoin Cansus the men waic pear's.
#
# ROLI: AThame mucher'd ow heem't inst and mhathad the gersssais;
# O sue
#
#
# iter :19000, loss:52.401115
# e gut me's soont a plold'llde, I wige moncand sove, hard tast goenst with moeligh-e fill t, tuce ex
# To frome inn ait.
# And she tret the all will thes I hachert but farmenin, am thot of my pree fast dai
#
#
# iter :19500, loss:51.801611
#  sher worend the wiar houlle!
# Thavele, Rome
# Ip seres
# That's he, Eles Ists, wat in isob suln? ire you wamy:
# To loth ow ther s
# Noullesel: thoun Viss thee ich, is thes ke the liinsen, statieny rot so ark
#
#
# iter :20000, loss:51.724040
# t
# Firce,
# Horre?:
# Tunt amalt o he sise; mecivase
# zome the by wit ther by!
#
# MERLUTY IU:
# And come slukbis prailirs of now haze or thim heas In have in have in mokice bived bucad troull thoues thee he me
#
#
# iter :20500, loss:52.089273
# d hing omes, alives, you than!
#
# JRABEWCE:
# Ofalio of me ncaise.
#
# Nug siidat?;
# What hot thive me tumy than Hon'! dot reethoul eling henay; eyth, thour thin?
# And peads, shay' martss;
# Leak thil lyon uspan
#
#
# iter :21000, loss:52.199668
# ollor hy light, myter'd aid, uin engore I trirak,
# Astilegod, hot her thak iny not-ho Sorsoon, oads
# ssy withen still wurch, I lersend not so lark.
# O ow lote.
#
# LIZAE:
# On of a lirgts you neges an ever yo
#
#
# iter :21500, loss:51.485639
# r if ce! I dileste it, buke manny
# Or I wise eakh hime,
# And his to'th here boit siies thrich:
# Fithir in.
#
# BULIAT:
# Mortosciorimel, my barth,
# Thy lathem cay aring. aut!
#
# BYOLn:
# Where,
# Cechios that noy th
#
#
# iter :22000, loss:50.954110
# lace worrece.
#
# Nugxt hire.
#
# RAMEBRIET:
# Cith ale
# To mite, morr ist sa feaker muroue.
# Dfe mebend the to fut thees thireetes'd so, ble up to the frerst;
# Ormun nelsir;
# My detems clong sut ubore; shumg wha
#
#
# iter :22500, loss:51.563610
#  in endee:
# For thet--yersity on me zirent;
# The, proan:
# SRatherr
# By haich:
# Tow thim cain be yom and frue for limbry sumy the me taye thot and suriens them the, If worr, up ameed with wowreted Lirs.
#
# CO
#
#
# iter :23000, loss:51.285987
# nown.
#
# SARENd:
# Duitemall qus limparter, Mige or. of ure walen that is If, Hith datither? himgermedend!
#
# BENGENCHE:
# I dather!
#
# CAUVEEO:
# Entoll, welle sure kencre! whold Hake and manghard
# Whtie you a jo
#
#
# iter :23500, loss:51.066737
# uk pa dee or not an tuld stis has, Thire I bewnale surm.
# Ny proof a, couns howy for I sot he pit, wath the ake this I wris im yoor lering;
# At reord thee mane connof wileed ping fird so sall seigh thim
#
#
# iter :24000, loss:51.213318
# s:
# Whom my ast loking hey and I hith reef,
# Ne spear in aruch freppea qutowf cot buwtrine, I bror towrob
# And he, hy hose fick fareyd wet Shar thy theen ploungowings sertean wans Ligbink of Yee carkins!
#
#
# iter :24500, loss:51.298545
# d-dide wivl, the bordy o crove the dnitfo it,, arat seit thinget,
# Eivery, Pince
# Tus be.
#
# DINCAPD
# I I hise to winh at th stin tring, that upang' per.
# Anvo!
#
# CABPII:
# Nat reaucr, reat thore neagutersen,
#
#
#
# iter :25000, loss:50.566365
# is sis'd thou my love this govey,
# To lare wirire, Eneart;
# bothing lave this dadbile it athat made proad-
# A
# CHARD II:
# The earst,
# Hee shae heaps trours that -are oup sore frey thre soan.
# O dor dock
# Nous
#
#
# iter :25500, loss:50.446161
# rd Gwarkere
# This saven conrosfof, in tit amald eard in then form.
#
# RIOM I ling fith mung,
# Axce
# Wich thores Lixwin my quied air so sereiigongoy; houf, I the thastelf
# Tuld sis, Kicken bate, not here the
#
#
# iter :26000, loss:49.699648
# nce
# That krwid ue a let you forfay ke'd Lores uppeant that somboun you thy,
# I Hecht.
# Kees jouen, me ist and's now could, elen washe!
#
# LING ERIS:
# Srucbes.
#
# WI EXvizy a but, cathigemqrtow with thy winfo
#
#
# iter :26500, loss:49.600129
# ws, ay,.
# Searfe arore thy o Lapeus hoem harr warrowngle, as thy agher, Witcer tithTher:
# Seard heprost not iglter.
# That it noth lefce casserie,
# Not if Where my o, manntos of if spoor not that?
#
# ALRARD?
#
#
# iter :27000, loss:49.372893
# is ruvy thamus his.
#
# KINVt:
# I whallly's that the me wo desenesse yind owers hent'd'd treat the pake tere, Whadms pruve love stame ure of in munghe's
# 'ly's chonds, unt ghall, I to a, hou a what is thy
#
#
# iter :27500, loss:49.288769
# le;
# Bade have fams murwers youl falef
# AREHR:
# Whenencl'd and.
# ;
# And, Ifser.
# Os not ray troy-l int Pthal Thourd?
# As bet ruch do wigh, the peard ant, withs be: quwlisoy! whibety me will wend, sene korrwe
#
#
# iter :28000, loss:49.278110
# then froont my breacter.
#
# KING HING Govesr thou the cald the shead my lut is acther, spite dise hight no that othea' wiche thear,
# C the that to thou; ang thes thou the is kingr? in sien: magaitcer;
# Fo
#
#
# iter :28500, loss:49.420103
# t Yot spingust to with macees, my be thaice; deak liventy!
# Yeg
# As wim meaverse;
# And hich as thou det as eand, if the gony, with sut sup, forupfe,
# Dowhre to ancee toutcief!
# Af hemr aiins: sthen,
# Bus ra
#
#
# iter :29000, loss:50.738342
# ses?
# As sure hat Hasbondalleld of int should iveint.
# Be.
#
# WASLINGLETI EELIXGLEDWERBIIS:
# Edd youllort thas vinrshing:
# Yet
# Thinse, ureart is he lensanence.
#
# HERTYUTHE:
# ThaMy and a hacke,
# Your
# Sridh.
#
# QL
#
#
# iter :29500, loss:50.966314
# ct ofon spand now for, in tere
# Het not o'll all the sas to deae he thestlence
# Edy whe shigh not,
# Aw tine precomfand he mastss thouch sies.
# 3orn'd Gombutem,
#
# PAULINMIULEZIT II HENGILVAMELII:
# Tuscrere p
#
#
# iter :30000, loss:50.913468
# le is I life,
# And.
# Agers;
# I thist twacendem
# Preindence now Menty. I with llack'gef as fellenfor!
# Aro your crurwof on I wot,
# This pralb ear: nvill'd art anviss
# Theserss
# Wheray
# Anorguch Lord
# So this the
#
#
# iter :30500, loss:50.841611
# k, sharghio,
# Thire Doine good pone vaken
# ore it brilet hisadn, I a doad the moll in to ping frest he seo? Papor
# And'mpent this my need are but, a theer tua my
# Mave to hex? you I'd bake, they boch so l
#
#
# iter :31000, loss:51.401582
# ast eate.
#
# OXINENE:
# If erthoy Rastard me rull, ever: fre the am thastsis'sen bronlared moagh-Y in cot the d? ba pranglech sacers hes grace, and o me da
# beet,
# For murst dives you my chaldenss the frord
#
#
# iter :31500, loss:51.867917
# plester me, the wich wheeph:
# Slay.
#
# DORTIICA:
# Thiw wore
# ond gherrtlakin pefpon, cowing
# OR oulat lotk fol furghss a lainy.
#
# Wirs fave,
# Yert of so sim.:
# Ant oud arumed my peet,
#
# La: Waich.
#
# LORY MISqHIC
#
#
# iter :32000, loss:51.421515
# seat!
# Whis Kal'nt a lave luch poisagaoked fief.
# -Five Faty hall fits si dryeck
# Thang am he meag.
# UJ
# Teat ste me pat' cimy wingh my as you in the wire ouy to dive pray.
#
# Fentchan wish think re, a, by y
#
#
# iter :32500, loss:50.681101
# owe:
# Arthoom reteld hast: wers, toun;
# O not anong,
#
# Cofe math hank of thous; shas alion,
# Of Goof nettus oper: allire:
# In Vamlon,
# Yot om, Ple;
# Mawioneds.
#
# MAMWOUTEN:
# Nou hes arus
# theret them duwnlles,
#
#
# iter :33000, loss:50.289125
# y bencher arrose sokt:e aring and mmey us jesoint
# 'est.
#
# CAWWAUSI Enou'ld a rainen:
# I rot bean offbes, whoutle porll, are, the will therearenan broverroun of wave cougrthe a bucker, hou dad'tend pled?
#
#
# iter :33500, loss:50.213175
# s
# Ciovent oth shoum
# Thou?
#
# PADYRE?:
# Yourd the
# stiride is.
#
# SILHZCA:
# Ning aoun not bothen and houn a sloss; is not veltant
# Your sil-.
#
# Gighof agh of the paok san Last be recle my maiucgelnt my
# quive,
# s
#
#
# iter :34000, loss:50.076991
# pawe on femand this Myang shetd anq evang trefare fou witle, dervis
# To pros for in jeriens these.
#
# FI! VORDI VI:
# I to futhmpince.
# ;
# AUThen:
# My treans,
# Now deary hantand?
#
# JUALEONA:
# En to feris;
# My mes
#
#
# iter :34500, loss:50.589174
# tocaod:
# Seing as houcs a to do har? thee hire ount, to the dosse, frenam fit cornce it be omecrist docl acersess
# lut you tout lits, iljone,
# Bear. He's alainia, ah sonepy may ige, Mare desiry tor:
# 'de,
#
#
# iter :35000, loss:50.209115
# ,
# What the thee I mane bay tow bes our king, should
# And esivny his and gut os from For doll: my wnop ands harrserst be seves
# .
#
# AMAREN'EG
# Lo; I?
# I grabfeatent bpoo; sor'ster,
# Whom it,
# Be theppory a, m
#
#
# iter :35500, loss:49.853933
# ucn your jom in'd nensomood that sim ep trreancantat ofe bad; sur:
# That to shan:
# You,
# We prose thy the wrould a lepet, seres, Ith pellselx,
# Fump oplens, your by, sting ore fnein,
# I' hispinowa anouty o
#
#
# iter :36000, loss:49.215127
# .
# Whim, with
# Mett fouth prads ching
# Thrroursther -hay,, as, shousharl, by noin it ingorent it mam the Godtend, buceWert wull then har,
# Wos, be rod; ar pore dearsare, ule.
# As, siech hiseoresannt, sick.
#
#
# iter :36500, loss:49.272024
# bfeded heaken's not be and thomearm, cansoy
# a ife, shans,;
# Martiner gay,
# huse witheh, In?
# Tle; bain diid youly Phing of yoR with is a feaming the oof, Kaives fee uran you as for you poustongessinay
# ul
#
#
# iter :37000, loss:49.332403
# iss frise sisead, be carsiis so chince ove may ther that Where t larcn Ino vaid; atke snow in antled
# Bet be omat, that ewe herch not cutletel, with bust uy anard, come veard, to dreve be robee ther fr
#
#
# iter :37500, loss:48.891138
#  On this hormand is what celleng pructius sum.
# Weateding.
#
# WiG'g you moustwings hast goyne whings
# Af aloud to stier.
# Fur Cowne!
#
# DUKE VINAE:
# Three on, wimp
# I hejestend, bus dechurs king fe omay: brat
#
#
# iter :38000, loss:48.560997
# otire, all.
# Bvome woor mouvonce,
# What hos Youch shimch, yow fruy adliny my caidy
# Your hisk fate and congaitak, us stou,, wan my trifoun retate not your ye'd ast,
# For aly Monk heve
# pricqunyen, bemy, be
#
#
# iter :38500, loss:47.987858
# t glave staer onkaid
# Wo collr, artety.
#
# MERLW:
# I with on thringes ofn hereiscesisther poin lempe, nous dy gast to having iftece,
# Shan the grolg and k in thin barstent not is hece dike tell fediarner;
#
#
#
# iter :39000, loss:49.187193
# d ast good had
# I hos loudn a pary her copice, and as me, be a I, cout:
# On to I qupacaysh.
#
# LUUENTIS:
# Angon'd in. Benire farwesborilerane, fall you wacdige ty tout, no garss, exengy, anct ssee spaitom'
#
#
# iter :39500, loss:49.919152
# r, to Methis,
# He; chan, ang a for he her!
# 'torel'ted, you dore mo my thing.
# You not mad anry, Gor the movist rat; Abe tadle if the fabrintmur be frale spoll gruch
# sore not not I diveirsoor kle?
#
# DUCEN
#
#
# iter :40000, loss:50.271107
#  thou seres me soon by my lird lither goon I reriod,
# call and.
#
# KUATHO:
# Begert:
# Aid led wive goadin atrostly, it I coor.
#
# RO:
# Poming thows beingiund abotinar; bemie, ard, hey tids,: your thourd wo put
#
#
# iter :40500, loss:49.544501
# at artio ast's, that a and to your.
#
# HAMIO:
# Beake!
#
# GRUSIO:
# That I lat in if to ksther:
# Yat it, he, wit quing yourier a myanger that you stener the pull: be moods for strincade masty,
# Pry, stowr thang
#
#
# iter :41000, loss:49.684833
# or:
# Agl, gast daitciss, quaitis and,
#
# if hee's care kour to velk, a doit theaverace:
# I kmetord; it that becioine prespainother, arlfor hered Ipsad berin?
#
# GREN BE:
# I Chind, trewentha betiotoner to wha
#
#
# iter :41500, loss:49.343482
# s concoun,
# Hes saloman, File hal my his, beacht wat bin in the poresmaynr, the me of hey the prave al!
# There havead?
#
# LUETHARUS:
# Cothas sout clare.
#
# WhANIO:
# Whuns.
#
# BATYMIO:
# Pieds to ree, onesharsald;
#
#
# iter :42000, loss:48.975243
# a knowd beopelf, it to sum,
# O be bore co!
#
# BIANA:
# Ed wow that Gos:
# Thysenduing camant and thy, by the the staly these coreio Pastt shorus upann ou fraght,
# Whant'd,
# Yoor:
# A virigh preas: thou.;
# Theinul
#
#
# iter :42500, loss:48.158342
# mink, tis dite thoun a beders waghad and haiging of Is, hare.
#
# ToNATh
# IIO:
# Withe me, tho' hars;
# Am. Not sith, my wire seld to me soaks, bet.
# I hove I hing poit wood?
#
# PEvASTA:
# O hat I'd-bel say him co
#
#
# iter :43000, loss:47.473021
# m!
# And you have you maather steend of sea thou he lomeff?
#
# PEPRINA:
# And no would myast.
#
# Hyou carals
#
# VINCANCHARIO:
# 'TA Of upreded fe rrens on to be will tow me, womaver-' chell geant make my in shear
#
#
# iter :43500, loss:48.371616
# e theertes;
# I do staret sol iithle,
# Thou mad's goceds manoo?
#
# BRARITA:
# Thee that
# Ta comes tile, it sake deebhe fiit o'dscat
# That for mothirece
# Thy ead.
#
# ION
# ORIO'.
# What, soath, stix'ss my endef ou?
# Ko
#
#
# iter :44000, loss:49.485640
# s
# Hes:
# Have.
#
# KETRO:
# This ge spive of ling in's it-a in the fors a Cuchiedichoc. O, sif. Ith. What warder hing wouldy me dive fave ha's ructe sisence col-ia sind uiined denes.
#
# ANTABASO:
# More nemain a
#
#
# iter :44500, loss:49.700137
#  thee peacout the pensoond
# Whip,
# This wicine of that you as.
# -hirwher fasty.
#
# ANTI::
# A chome, a ake inties, thy bried Kake what my througe;
# Then divefed.
#
# BELIO:
# Gndoo,
# The fetikl stel thouress of de'
#
#
# iter :45000, loss:49.789542
# rt, he yourd-.
#
# SORTIIIO:
# Thes able.
#
# VEMAPEY IA:
# Comed.
#
# Nore?
#
# VOLIIA:
# Here of thare.
# Here in her, haven dietuitaty.:
# Beserd.
#
# VUPEINEN:
# I giverouts thee,
# Hathen and why!
#
# VORUA:
# Thow to comien, for
#
#
# iter :45500, loss:50.408217
# ge;
# Wees.
#
# LANIINIIU Vingut hich shoor if stiming fot dirdt o eayt! Thes? Not! Cnory but, yech sards I ence; whavaring thoughlars, fith anviny,
# A gove on that, to loold wister be've bowed the peakien,
#
#
# iter :46000, loss:50.191799
# eve.
# 'le, rrack fas I rath will my knotssigs undwuced theancans tha hancy opes
# pook'd gofly ngomadsely hem hest of wouch hel yecir loul so dig! chomsen of goor, hink of thim
# It thee mady,
# Lem Mig: mos
#
#
# iter :46500, loss:50.081685
# d it that to gut: she baad,, theur nhorellennther, thzy Kensintores manavy
# Aut But to thete:
# Trein:
# Pleake
# What I one pecandaitlers, an? neremodinn motuer, I an'ther gond thel Coor hise mawn, you more
#
#
# iter :47000, loss:49.402368
# e whibe achiree:
# Anobuethben sin shaleto's soid not wirdy.
#
# CORIOLOLANOUb:
# Onde falling jon,
# Ife pouke siry 'y'gr of that urefornting, he faebrout hered foo lather his evere'ly naly,
# I' paies
# ntercan,
#
#
# iter :47500, loss:48.646616
# Watle: Cinsy heralivy end the lave denood sum sirost you up: maun to to in a but surs. Com you flien,
# My, I chancis, it troum, ther? Whes hant to to you more so, hy this hats,
# I marthh. Whou haf Main,
#
#
# iter :48000, loss:48.095908
# t:
# Souls'd inghed do loken: Aboust edimos?
# He was conrukm bise, commat gever!
#
# ANENIUS:
# Then etting;
# Your as our the pisee in a wiviss his the buttek loves hach
# whies wofn und, yee himy not yuver comr
#
#
# iter :48500, loss:47.780264
# manoN our marts they hall
# Met.
#
# VORINIA:
# Notre to sove evean's thece the I fold.
#
# VORINIULUS:
# Busthand soor, and be
# Thoukly nosids thee deave;
# O' him I des I rad thy mood:
# On he
# anterme tore thoull wr
#
#
# iter :49000, loss:47.629492
# me.
# To chom ed;
# Hat a ofda: bast more laftirenod be, cheas, whainlych
# Ass cond I ughin we comties pursiter:
# On he mancesen achurr-stire
# I foubped?-
# Bay! the wish himbinis; your ip in ar is coon well a
#
#
# iter :49500, loss:47.857607
# ilk netgogaplirs it than thim the ratos, janiat
# Thind,
# Pras you me deaple oldly, not loke sheae!
#
# COHIUS:
# Dare therner
# As I soan:
# A chas, tell giedce:
# But doan:
# Brtop lat whatuss.
#
# VOLUSUS:
#
# MERENIUC:
#
#
# iter :50000, loss:47.818494
# ay:
# Nould a with ture le how whouse.
#
# MENENIIA:
# Becaily: ummonk. I come
# bligh, him would, And ublide, but to Gedpestice,
# Far 'tall
# Ard for vell mongond yit,
# Astoring it thee heat, him a coulk, I offou
#
#
# iter :50500, loss:48.289966
# esparisned werllay
# 'lousty
# 'ges Makeop your me tire thy grepoth will hast,
# Lether to shave toulds youre to have moofny opluse on yeried.
#
# CUMINIUS:
# No, are.
#
# ANTINENICLASTUS:
# I
# you sterred mavinglrite
#
#
# iter :51000, loss:49.094012
# r weer a
# plabe from wosh I know five harmy swoladsies'ned stoble, youre both.
#
# GLUT:
# But have vad my thee sull pead That blound touse sir.,
# Grom.
#
# GROUS:
# That the wrich enthones,
# Yet us cont o's as an
#
#
# iter :51500, loss:48.519434
# l.
#
# LAZTRES:
# This I grempabadsters, my mens undea trereas paboud, theathike,
# And thein to with,
# And for I knor frie wiply not suct
# To lowns! Clospouk?
# You and fins, thas nod your mome to I greategh pa
#
#
# iter :52000, loss:48.628990
# us!
#
# BLURENT:
# I ind steemich.
#
# MERENENES:
# Fur fist.
#
# GLOUCESTERY
# AUS:
# Abe shea will, gover:
# Your nan'scare ie theach lloughty five, queaty in she to nas bere, be my and wo liderine ied him the douod,
#
#
#
# iter :52500, loss:48.835583
# restis on he poader, in the seusn. But.
#
# Noker'd thow doust wakomelg tis secbes!
# And hise the thy kand's his to, have, for thes me to houl meeserly till hist dowe and mondirss!
#
# GLETY MAND:
# I granect
#
#
# iter :53000, loss:48.302785
#  ynors.
#
# RICHENNO:
# Mave kelblan's him his' caming it boveh,
# Shorm, nost thee and swrecce a cothey:
# Heacl
# Wefull he gader's
# Etwim! to furd?
#
# CORENS:
# Credt auths do calitce for hember 't.
#
# MINENS:
# Les k
#
#
# iter :53500, loss:48.283347
# hee me to dyan ple, nod 'terwobes so concles?
#
# MI kore
# But him gomegh. Hom, the,, and mothen chall do gook our then to Colder! They lommy himV,
# And he plath.
#
# Go decoor, thon havl the the our sacist.
#
#
#
# iter :54000, loss:47.467672
# d they he ceiod loidy, Glothwarti:
# Thow, hat't grong then to that you saly a that givice, you.
#
# GLozE:
# Y thau, toll id their of that co, loke?
# I
# Endweld say not like a fe loudt,
# I it a preacls hatce a
#
#
# iter :54500, loss:47.356338
# ncef rivegutecis werelce;
# Beath woth my hispiaize
# To book, as my vefore is to grigs asch me not ig and love Mamess peaththall soon hare whye toll mein yoor:
# On Fivice his name Edatd marpathak you whol
#
#
# iter :55000, loss:47.571806
# sumalf thus roldy: sho my dist felling.. Wher himp'ds les, in thou ie your
# Core apt him, by warsel, dockull.
#
# KING RICHAME
# HIA
# Gos? protd sood houl lords.
#
# ETES:
# Feptnle he-d.
#
# KING RICHARD
# Cuightern
#
#
# iter :55500, loss:47.471698
# larty.
#
# QUEEL IING;:
# Thie ksrucusiof's deverme.
# The leer doak wras howis poar, Mes, the beave.
#
# QUKEND:
# Sow aw toy,
# lakes of that they notiok walboser is befall hene ander a'didy nother lids, I of the
#
#
# iter :56000, loss:47.136772
# H:
# To leip, what by with a of are my thing, I expiny sind ssiess come hispest ist an weacn!
#
# KING RICHARD CLIZABEN ELOUGHANCTHA:
# Sill why ciost coy;
# Hod; stly they of blork'd!
# 'rige
# Nor dears thees to
#
#
# iter :56500, loss:45.645022
# d with ture metring that mace, tho's vigh's shalf, till us teld he'sengin-sinfownle, bo herath and tither theeres?
# F ssoveres, briod Rar?
# 'st cordd---parmurse ark ?
# id than of, in and lightis, now met
#
#
# iter :57000, loss:47.748544
# , prean wak is fry what peuld.
#
# BICHAR:
# I shall conhay candony noo sayent it that his I a pocts Genst dack dacl hese yount wioros!
# Cleake:
# And the lad in my blatters
# Ed! Riege! Moroos,
# Whinve!
#
# BUCFRI
#
#
# iter :57500, loss:48.462566
#  derpel, thunds wim no ond of my. Of it gover a bist the scon to hee,
# Dy as Incore ly Eif minoule ore for ta crefnt ay that if I charcl bidine brom Last yow lither.
#
# KING RICHARD:
# F'ds of RughaLartanc
#
#
# iter :58000, loss:49.178145
# thenlebshoued rath lord'd my llamp masd chy in lathy pald,
# Whom Lay!
#
# GEY INGHI:
# Nos with rade send to yours enthen treard o clarty,
# I me
# poan louch on at thy?
#
# BICENR:
# A'ck nall
# Or to the
# Righ well l
#
#
# iter :58500, loss:49.058629
#  hat me, and sorly:
# Uvistiod, no aites in swore wnom les piendibrous, terwike obyertars.
#
# HORK OBAN:
# Whomed alve.
#
# MLOLIUFIST:
# And the soes lord,
# And in sheathen mode, gate the; Galy sen;
# To brom tore
#
#
# iter :59000, loss:48.961981
# appescest ourt to my, herter'd foreaase my now llesule, you breainbsald?
# Whot mone abycrink that to thee brom'd an prond
# Tore lord,
# On the tyy ban a make may ip, Tome menselly,
# Wher mastled not me to
#
#
# iter :59500, loss:48.783265
# GORY RITHARD sony, homt!
# Wead?
# But tot o hanty madfory suble Purthe is more I with you them, sping burs, deen to the dveans oud That herait sut ride obtaitong made
#
# yeswh mand disinagen:
# With my llarg
#
#
# iter :60000, loss:48.870074
# end eijot
# In reserand him?
# Axme not where tright my ole maco dogn make mike had.
#
# KING RICHARD:
# When be limst wete korr houke how of thywes like hark myous bothow koun, byow in tteiring cron bring of
#
#
# iter :60500, loss:48.433074
# mast at'll.
#
# DUCHENC:
# Trrath,
# Arr me sham'd his whall he, mithert my food padt; Deing in of the haled in
# Your up perkades haw must
# To broven sseacerdy'r spad, to sno, it our, which me the eet with s t
#
#
# iter :61000, loss:48.635891
#  wears st?
# No love to wall wren stanop denop mfovertel feave:
# Thits uring'te:
# Mown as the your soal wind in be tnou comanged not so sont; wist fasts de neges marunce we loidy,
# ATrou soor radnet in cri
#
#
# iter :61500, loss:47.837501
# re no care, thou dom I's my wark'l!
# Dorgeply and
# A pruge, theempneht
# Norle sarks; blood'd
# Fieght to sof thin.
#
# DUKENN IICKI:
# What I hou tricks.
#
# Firstin,
# My doant ,ears?
#
# HEY KEv:
# At reclaking or wis
#
#
# iter :62000, loss:46.674837
# sast woull and but in shadle
# That a nron, thot I deoust by from thol heaice I loves,
# And mose betther.
# I; fopeed, thea, be spentern trouls, brooy.
#
# SBROMERIS:
# You, negtet upor, of on Lenden?
#
# LOKS OF
#
#
# iter :62500, loss:47.573057
# mange,
# Advienfew, weciet ban yet soud.
#
# Frrpeldy love: mer that digd seves the sug: I fitws upy bram; I day will thy son thow in ate plon,
# The fartersule her I dayow,
# shall ie the bey deaus, forwor'd-
#
#
# iter :63000, loss:48.473320
# oksw, and alay,
# Pleansive fee-d
# With ubins and The incoyon youth he pur nast
# Ank cotcines, in whoun, his sour ceam, hes live in'll try hel lrang a valing, men bocte fint
# Hemped fapate 'tiry un.
#
# SoS I
#
#
# iter :63500, loss:49.380036
# se helutce:
# Brow.
#
# ROROME:
# Rose that frongord wath a fotewal'd, speest hon'nes
# brevels me.
#
# JIgh:
# I of For hou will hen-le stowerty
# And by come bet panghy surch vine wair'sboult my,
# All not wint by th
#
#
# iter :64000, loss:48.574783
#  underson.
#
# DUKEnBEME'S:
# Beet of. Butlenti.
#
# BULEENCE:
# Nure will lear stenly, nould
# I on foltains not grock achir woll comeoparty hareppliny it and Eese of the youl wime ar thead
# If till is thang is o
#
#
# iter :64500, loss:48.704327
# blet baly chine.
#
# HENVOMIO:
# 'sel soweling old the mell that so:
# If suns;
#
# Jull youly,
# Whou: wis thy as but af thou to a pam?
# Due say dids;
# Thingent ughtin will by's your loust
# Paart heach! O brow! ken
#
#
# iter :65000, loss:48.813956
# thangs to addard'd fourispaltof doed. he poepes my did hel: thy bloesen and whombeiod. blany do shaviend he meatomen lovemag mes me worll
# Agr, the painten uny mod,
# Toulds and tho kime
# Tey with, a he c
#
#
# iter :65500, loss:49.451756
# me the aly a in lakes sir, to with collang,
# Be woulf ret.
#
# BOMEO:
# Yatrjot'd? I the thill she
# Harruring in;
# ABeake;
# wownt lage incrites, thy lejel, foo this woncued:
# Houldee ueclela-to dife you cay ser
#
#
# iter :66000, loss:48.607384
# k than:
#
# ARD
# ELA:
# Live ment.
#
# RICHARIA:
# To the thatk shapt deave wate fidh olled not thy loving them I adsbe, my but I dias,
# Ho'cace, are solile no drath mode the me sowes
# In meces
# Souls of farl kill.
#
#
# iter :66500, loss:48.099083
# nersured:, you, in Loth hetaly, but gofely parselte!
#
# JULIET:
# Sicaltwad:
# And, ear!
# Fue broughren smain.
#
# BULIET:
# Heand pentaig, she beer ering wastw certhus and yours?,
# And heped wies goor the didser;
#
#
# iter :67000, loss:48.704660
# oun:
# Meashay my by deadle mad that Ronees it this soll, have teok; the sealf, art her
# Aop did that doll is cetien:
# Wo do more I sharisce, nose, thes goferder.
#
# SILAULEO:
# Not! Ta'dy,
# Than for though se
#
#
# iter :67500, loss:48.835051
# ath my lnesh sublan:
# Thou sid Andored caent
# My comtinteet; ag agk that with I witk to nouch.
#
# CAPLEMGEROLCAULIO:
# He'ld;
# Thyse?
#
# KANGAR;
# ETdreart triss be lome sitth, wholl beted it then should his pra
#
#
# iter :68000, loss:48.441818
# I of' hears amfrtw hough than shall spaly morife bespert fingake Furder my vett:
# Yeublem;, Prinnt evelthee:
# And like glape the is hill myne:
# The wharm my not bet!
# You off tere opfor;
# And that Seroy as
#
#
# iter :68500, loss:48.375838
# ashan;
# And of frath coues,
# Seves
# Arion the feardent uptook the noth igvouk alvatingen to arr of fas agfainad but I ray maty.
# Plewes'st browes:
# Bus vawh the buhs brundead! Ascors in he what cagel the b
#
#
# iter :69000, loss:48.536296
# sersowur cerce
# promgible
# The ker thos sin retssead soy fore and the sevioks you, fromy tist upoth;
# I call be tle
# Ans be, for nith verbrty ot? qusatarl, then brack.
#
# BENRABD LAUTHISc:
# Whis?
#
# Flie dosh
#
#
# iter :69500, loss:48.041629
# w on no that he poldss ant to Rublor,
# Ox the heakero; and awn not then stried.
#
# RICRING RICHY:
# Whim,
# Hereask now murder!
# Yorch:
# That monds, mantood werl do,, fory do nciouse!
# Art theave befor made, no
#
#
# iter :70000, loss:47.810174
# e would with bock in king,
#
# MEDY ID:
# Ard there such whou sa queck ance ey, goon is a kin; ask for toors a with tilee's evile your of in blowd:
# Aly, my are seem
# in shall penheres ching of Claity ourdy,
#
#
# iter :70500, loss:46.541626
# ack!
# And LAvin? by hean corrysle,
# Hos wailn's,
# Stathe the pail stithlo by crivisthe me ear pught ture thou plose, hesely ivid hes lime in whom Kove, I mier bathern his lave Hences I iucs, and by lozer
#
#
# iter :71000, loss:47.062998
# s mary sother?
# Tharch not is daysed Sepomed.
#
# FiRAnd STo mad Live agesde and and tha didide
# And ang I wive noon you teld, to dowet I have keneted, burder pleake mide of mo spatessaiod of whel it weep
#
#
# iter :71500, loss:46.683087
#  brovens;' home truen layon my safe proshio, well burion flestontise's in Horiln:
#
# KI
# CAREY:
# Where firkigs a love.
#
# Firstiled.
# Goon wall freants for a hincuplerety of knfledech blee eoftle
# Sintle ttou
#
#
# iter :72000, loss:46.664352
# Effataly warkigh.
# Alfors the seed?
# That hancfalf?
#
# CLADY GLEY:
# And shilch pawh conet-quelt?
# We fathe im, of Murcs, atsurt;
# Thou doth laicud's breives, a mands the couck ome bloves sind ridss is tharmy
#
#
# iter :72500, loss:46.678396
# er the geross arsed,
# There ingle shan, sunvt chounden'st froudsed coads ene will I oor I reimen:
# Chamest ust baine townr, For I lave be,;
# Mord math I brockent heardsgaporas conter fe ofagd the mpast t
#
#
# iter :73000, loss:46.461785
# TR:
# So bee.
# Thees wardent, shamofa
# Edwinf shabs that browir.
#
# WARWCEYS:
# With your himes;
# And may be thee crayodecest ffisse.
#
# LEOMEST:
# NoR years,
# We proge and thy cut Mightl nenclel'd ond, rimessO ble
#
#
# iter :73500, loss:47.969803
#  yee hine we Vovilt'd, and it in it the yets astand
# Mose you ture swall your my? Fave and as he be derge;
#
# POFFONGESTER?
# BLIZTROLIO:
# Hy be Iware and sulising our of be you brigg I this unding sing an,
#
#
# iter :74000, loss:48.464376
# ant as tore and hoth.
#
# PxRYO:
# And lith at and graany bed:
# But see that the liver not me nource!
#
# HENVIS:
# Plonkerqury! Liven
# Ssexpert and leap' to so .
# Hy ghall lies 'get ne tuanll my lords, gruiet glo
#
#
# iter :74500, loss:48.796939
# hend we's yousousing foul not ald!
# Caking ille, not do trow is houen
# ATtof, his frsier comen fallous quaking bron, by conter:
# And hen fale the was sal of the wertuptioued ghom not hous?
# For mapoun, a
#
#
# iter :75000, loss:48.557322
# n, how lageded thure tear there deame or a paicheton,--baks
# And a one let! The have heplfor needs doequay it shoos Home nowels;
# And as may thee to be fonter bepaigid; foul: 'veringes:
# And and mext ent
#
#
# iter :75500, loss:49.291145
#  frund me wopll undeclthing-ts and mman me, sert.
# Uupedt fnord thee to lord wnow the eerougl forllonnt a bent neford, for and nos them Ward'g of,
# But.
# The ears. But art youll
# Ay their: age; noilt-'s e
#
#
# iter :76000, loss:49.912277
# , than you digey thead.
#
# Mororty I sey a fard sin aben,:
# To munt, you toll till reastand this the all king, youm, pacham a pall deckest grithh grave dond a deaths;
# Far hase the.
#
# DUNYO:
# Slevom eshiter
#
#
# iter :76500, loss:49.805251
# t I'smabthad'tthers
# 'nell as baites,
# ou's, to feess my, prowe mane I micksell to, hes for soon you plast good ow stissen, and I offe soweftion to to hain, sorill booniser's, lovid
# Whild awe nend,
# The
#
#
# iter :77000, loss:48.817281
# o hims: stenert-lop nee his, the fake as pasce
# ont, Romeinite hall yot give fith not him gut.
#
# God sirssit som: on
# Noll of her you sprom for
# Thim distessel shis; his a bilirns?
#
# CADYCA:
# Date anr had;
#
#
#
# iter :77500, loss:48.368967
# onedsfor: ala of able man gure-miny, The betiinge fries.
# Hur which, notery fear tis loket them be wher fith co as dayen this you
# Five in conay fardin: the wow
# Pnather,
# Wifoon her mun, wich:
# To the dep
#
#
# iter :78000, loss:48.378248
# e,
# 'quill'd fath id at your the
# gefandow shall were beter her know arte and thou now Libet'n to caucf the ssichos. she the mest. Lorem them, ey giespies: our sots to fueth courores
# I ligh live
# Ne clou
#
#
# iter :78500, loss:48.037578
# gringaavet ptlorlter them she wat in his crithap; of adaids alitall for it ser deothly mine gue with he fnit soul sitht
# To do
# jetiner have stith to ger.
# Good ey us deather mad bust thald hondur it uy
#
#
# iter :79000, loss:48.428397
# n. Sto;
# Ind
# prither,
# Save have onees anwhe
# Bily you won's' ane'm as mance wate your, uppeccalce the thouke wangrace alan?
#
# CLEONCES:
# I not fidie or to shee, tan ok swild-hom lech.
#
# PARWORII:
# I so;
# We
#
#
# iter :79500, loss:48.202756
# she to, hnow his o fiut. O fasthink, I I sull chick
# Froth't tith:
# Woul is no look and Laid
# call the ay spee, I Kame the sered to Candomy, prop.
#
# LUCBOMIO:
# I, he the crame ead?
#
# DIYGS:
# Meates sirm't: I
#
#
# iter :80000, loss:47.719508
#  your you our,
# Veal, I'll loves; bifesty potolet ut our not nover ie hert heard the hith ast wher us serve, hronk mancoray,
# All, soledes shaid!
#
# Perot as, maok.
#
# DUCILELNUGES:
# Of I do shonguing and, f
#
#
# iter :80500, loss:47.331785
#  dreake to thou
# That dreaced lord,
# Thes and of y ysurir,
# Why dilcs t'if, this itherntia be to bsall he thesser fith and atcet, eythen the werd her-will?
#
# LEDUKIO:
# I'ld.
#
# DICHES:
# Whour wo'ld,
# Dhy my ma
#
#
# iter :81000, loss:47.365043
# my govarfer: Ifthenon as uppoan he hemt ithins; as
#  that jose my somomt,
# Nelion be no so and in owst. As I breast?
#
# AUCAOT:
# O, me whigh the easting ulvenes:
# Ind your Cantcourd gioun was deakaif frich
#
#
# iter :81500, loss:47.131607
# rspit to low?
# Hy thant.-
# we loves confe, ttaed.
#
# PUCVEY
# OTE::
# Lonk, his diegssterntires quivets licgit auving,
# 'rnoble the everiod's golds, not do thine morubard dowr rice; afe spall, haw if hasts nor
#
#
# iter :82000, loss:47.183894
# a butt move tour and by, it ip
# CI pore; a but of I but that if your thaie hille a madaved soble;
# !
# Rend leficonoss not of most:
#
# ELAOLORIO:
# Than: has fich so corefor and the eanfigh nott is id say. Cl
#
#
# iter :82500, loss:46.718185
# i: is foret.
# I, are
# But, hour so worickion.
# O be sick; hor to whiff conom; bavy mu.
#
# DUKE VIND:
# Hot frow arrtan, for from to deirld. Any thet your
# come in, shel, an olire.
#
# DUKINGAS:
# Bath intsiol the
#
#
# iter :83000, loss:46.122485
# I dot of the turoull nelikes wast he rivindoss af thiw'll Rome sasty.
# For. Anr mo.
# Mor bontike O is mestor commarian.
#
# JUPIO:
# Nodrows wo know he re, in a daroungar's dowont.
#
# Lord
# And Shink dorder her
#
#
# iter :83500, loss:46.973675
# full befory arie, soup' compulle bray, him thinke do mantse, As to stighty ther with I no, blomes hiwne.
#
# LUKI VINCEO:
# I peace by the dut the foucesiontes on to llag in fat you not ap, wicko-
# So pelve
#
#
# iter :84000, loss:48.203842
# -
#
# POFKIO: SArto'de trow hisho: veke noo yourwy Pentorningedwe, Bear that and to ghours, a did nilF of thysertionel.
# By begis!
# Ke mad Gatter treags
# Suiny hour? Hetes poit
# Busin, weoll
# My furin;
# Ed and
#
#
# iter :84500, loss:48.696877
# d, a, I the know be bathen, wore you memper her jowt thoul wrom tap will ant goff come the the soper no,
# Sur? You me otien styen the spret'p he
# joots abdat, highly rad pit weate To mange,
# And will hou
#
#
# iter :85000, loss:48.007875
# ,
# Bus towngeran not soll youn, you wasted thier my fife him in the will I trace now they raied the'll weme de.
# We treacion.
# Stwance fattshe; lo:
# Thin?
#
# SY:
# And but the himadost my mone, byists Ifuts o
#
#
# iter :85500, loss:47.700769
# ,
# I, houn go met' pain,
# O, ele,
# To sho cutrougaion asplell by stand
# her, Mosty prame more fimes citiee: whyee swould breaan,
# 'ty, stind by mas duth, sin well Lond?
#
# TXANUCITIO:
# Sare op so shave mpacru
#
#
# iter :86000, loss:47.660597
# ,
# Bheate it welloresor
# As at with, inton suhe sich good, you be not Ker'd ent
# Are, her and fare and dise Nust beaviry till whome that tacculder bror,, you mu kerversonciod, ho; ath he
# hem holl quather
#
#
# iter :86500, loss:47.544725
# td yot seetherer.
# I Bido'sel,
# Troous'd your in, I bust
# 'mes wad!
#
# BIUTHARHTIHAMI:
# And wile wit in.
#
# PETRUCENTHIO:
#
# GROMIO:
# I achisied and if yorrow I drace wath deat' soad,'d beaneslemnd bidwing ho-do
#
#
# iter :87000, loss:46.879636
# ? my rosh the,
# Glemlos, yau! condiesait the kive.
#
# BAPTISTA:
# Eread the have, Bemuch.
#
# GRUCAO:
# Let;
# O tribond swerthan you and me sleantry ald upeter feareds strem aw-?
# Pots more madin's, you
# If dointe
#
#
# iter :87500, loss:46.228446
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-09ceb2caa40e> in <cell line: 4>()
#       2 data_reader = DataReader('/content/drive/MyDrive/input.txt', seq_length)
#       3 rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
# ----> 4 rnn.train(data_reader)
#
# <ipython-input-8-b8f9869d82f4> in train(self, data_reader)
#     106                 inputs, targets = data_reader.next_batch()
#     107                 xs, hs, ps = self.forward(inputs, hprev)
# --> 108                 dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
#     109                 loss = self.loss(ps, targets)
#     110                 self.update_model(dU, dW, dV, db, dc)
#
# <ipython-input-8-b8f9869d82f4> in backward(self, xs, hs, ps, targets)
#      62                 #calculate dU and dW
#      63                 dU += np.dot(dhrec, xs[t].T)
# ---> 64                 dW += np.dot(dhrec, hs[t-1].T)
#      65                 #pass the gradient from next cell to the next iteration.
#      66                 dhnext = np.dot(self.W.T, dhrec)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
rnn.predict(data_reader, 'thou', 50)
# Out:
# 'thout boknot.\n\nTre I mover herder ofe.\nAnd Mitiei,\nNos'
